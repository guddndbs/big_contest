# %%
import pandas as pd
loan_result = pd.read_csv("loan_result.csv")
loan_result
# Out:
#           application_id loanapply_insert_time  bank_id  product_id  \
# 0                1748340   2022-06-07 13:05:41        7         191
# 1                1748340   2022-06-07 13:05:41       25         169
# 2                1748340   2022-06-07 13:05:41        2           7
# 3                1748340   2022-06-07 13:05:41        4         268
# 4                1748340   2022-06-07 13:05:41       11         118
# ...                  ...                   ...      ...         ...
# 13527358         1428218   2022-06-03 12:01:58       62         200
# 13527359         1428218   2022-06-03 12:01:49        2           7
# 13527360         1428218   2022-06-03 12:01:48       32         257
# 13527361         1428218   2022-06-03 12:01:48       33         110
# 13527362         1428218   2022-06-03 12:01:48        5         194
#
#           loan_limit  loan_rate  is_applied
# 0         42000000.0       13.6         NaN
# 1         24000000.0       17.9         NaN
# ...

# %%
log_data = pd.read_csv("log_data.csv")
log_data
# Out:
#           user_id               event            timestamp    mp_os  \
# 0          576409      StartLoanApply  2022-03-25 11:12:09  Android
# 1          576409  ViewLoanApplyIntro  2022-03-25 11:12:09  Android
# 2           72878        EndLoanApply  2022-03-25 11:14:44  Android
# 3          645317             OpenApp  2022-03-25 11:15:09      iOS
# 4          645317       UseLoanManage  2022-03-25 11:15:11      iOS
# ...           ...                 ...                  ...      ...
# 17843988   242442      StartLoanApply  2022-05-27 16:08:21  Android
# 17843989   242442        EndLoanApply  2022-05-27 16:08:21  Android
# 17843990   593062             OpenApp  2022-05-27 16:19:10  Android
# 17843991   593062               Login  2022-05-27 16:19:15  Android
# 17843992   593062       UseLoanManage  2022-05-27 16:19:19  Android
#
#          mp_app_version     date_cd
# 0                 3.8.2  2022-03-25
# 1                 3.8.2  2022-03-25
# 2                 3.8.4  2022-03-25
# ...

# %%
user_spec = pd.read_csv("user_spec.csv",encoding='CP949')
user_spec
# Out:
#          application_id  user_id  birth_year  gender          insert_time  \
# 0               1249046   118218      1985.0     1.0  2022-06-07 06:28:18
# 1                954900   553686      1968.0     1.0  2022-06-07 14:29:03
# 2                137274    59516      1997.0     1.0  2022-06-07 21:40:22
# 3               1570936   167320      1989.0     1.0  2022-06-07 09:40:27
# 4                967833    33400      2000.0     1.0  2022-06-07 08:55:07
# ...                 ...      ...         ...     ...                  ...
# 1394211         1864587   489900      2000.0     1.0  2022-03-22 14:55:32
# 1394212         1327066   151422      1955.0     1.0  2022-03-22 01:19:24
# 1394213         1319606   173524      1983.0     1.0  2022-03-22 07:34:32
# 1394214         1482466   766546      1975.0     1.0  2022-03-22 22:12:35
# 1394215          816537     3864      1977.0     0.0  2022-03-22 08:55:14
#
#          credit_score  yearly_income      income_type  company_enter_month  \
# ...

# %%
sorted_loan_result = loan_result.sort_values(by='application_id')
sorted_loan_result
# Out:
#           application_id loanapply_insert_time  bank_id  product_id  \
# 10972627               1   2022-05-06 11:05:57       62         200
# 10972632               1   2022-05-06 11:05:42       59         150
# 10972631               1   2022-05-06 11:05:43       50         142
# 10972628               1   2022-05-06 11:05:56       38          16
# 10972630               1   2022-05-06 11:05:44       37         206
# ...                  ...                   ...      ...         ...
# 9732104          2167826   2022-03-25 11:58:01       38          16
# 9732105          2167826   2022-03-25 11:57:51       22         221
# 9732106          2167826   2022-03-25 11:57:49       38         223
# 9732107          2167826   2022-03-25 11:57:49       30          85
# 9732108          2167826   2022-03-25 11:57:49       35         168
#
#           loan_limit  loan_rate  is_applied
# 10972627   8000000.0       14.8         0.0
# 10972632  19000000.0       17.7         0.0
# ...

# %%
x = [[] for _ in range(10000)]
y = [] * 10000

for i in range(10000):
    x[i].append(loan_result.iat[i,1])
    x[i].append(loan_result.iat[i,2])
    x[i].append(loan_result.iat[i,3])
    x[i].append(loan_result.iat[i,4])
    x[i].append(loan_result.iat[i,5])
    y.append(loan_result.iat[i,6])
#key = loan_result.iat[0,0]
for i,j in zip(x,y):
    print(i,j)
# Out:
# ['2022-06-07 13:05:41', 7, 191, 42000000.0, 13.6] nan
# ['2022-06-07 13:05:41', 25, 169, 24000000.0, 17.9] nan
# ['2022-06-07 13:05:41', 2, 7, 24000000.0, 18.5] nan
# ['2022-06-07 13:05:41', 4, 268, 29000000.0, 10.8] nan
# ['2022-06-07 13:05:41', 11, 118, 5000000.0, 16.4] nan
# ['2022-06-07 13:05:40', 35, 168, 21000000.0, 15.2] nan
# ['2022-06-07 13:05:40', 44, 8, 3000000.0, 14.8] nan
# ['2022-06-07 13:05:41', 28, 217, 10000000.0, 18.0] nan
# ['2022-06-07 13:05:46', 47, 181, 31000000.0, 13.0] nan
# ['2022-06-07 13:05:51', 11, 170, 50000000.0, 13.3] nan
# ['2022-06-07 13:05:41', 58, 175, 35000000.0, 13.8] nan
# ['2022-06-07 13:05:51', 35, 29, 5000000.0, 11.2] nan
# ['2022-06-07 13:05:39', 59, 150, 25000000.0, 13.4] nan
# ['2022-06-07 13:05:41', 34, 248, 43000000.0, 16.9] nan
# ['2022-06-07 13:05:40', 10, 149, 18000000.0, 13.9] nan
# ['2022-06-07 13:05:41', 63, 226, 29000000.0, 15.6] nan
# ['2022-06-07 13:05:41', 54, 235, 28000000.0, 15.5] nan
# ...

# %%
print(len(loan_result))
# Out:
# 13527363

# %%
arr_loan_result = loan_result.to_numpy()
print(arr_loan_result)
# Out:
# [[1748340 '2022-06-07 13:05:41' 7 ... 42000000.0 13.6 nan]
#  [1748340 '2022-06-07 13:05:41' 25 ... 24000000.0 17.9 nan]
#  [1748340 '2022-06-07 13:05:41' 2 ... 24000000.0 18.5 nan]
#  ...
#  [1428218 '2022-06-03 12:01:48' 32 ... 15000000.0 7.2 nan]
#  [1428218 '2022-06-03 12:01:48' 33 ... 44000000.0 13.5 nan]
#  [1428218 '2022-06-03 12:01:48' 5 ... 44000000.0 9.7 nan]]

# %%
x = [[] for _ in range(10000000)]
y = [] * 10000000

for i in range(10000000):
    x[i].append(arr_loan_result[i][1])
    x[i].append(arr_loan_result[i][2])
    x[i].append(arr_loan_result[i][3])
    x[i].append(arr_loan_result[i][4])
    x[i].append(arr_loan_result[i][5])
    y.append(arr_loan_result[i][6])
#key = loan_result.iat[0,0]
print(x[9000000])
# Out:
# ['2022-06-24 22:45:22', 35, 29, 3000000.0, 12.5]

# %%
print(loan_result.iloc[9000000])
# Out:
# application_id                        297360
# loanapply_insert_time    2022-06-24 22:45:22
# bank_id                                   35
# product_id                                29
# loan_limit                         3000000.0
# loan_rate                               12.5
# is_applied                               NaN
# Name: 9000000, dtype: object
